# %%
# !pip install open_clip_torch
# Out:
# Requirement already satisfied: open_clip_torch in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (0.24.0+cu126)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (2025.11.3)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (6.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (0.7.0)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (1.0.22)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm>=1.0.17->open_clip_torch) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (3.5.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open_clip_torch) (0.2.14)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (1.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->open_clip_torch) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->open_clip_torch) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->open_clip_torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->open_clip_torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->open_clip_torch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->open_clip_torch) (2025.11.12)

# %%
from openai import OpenAI
import os
from getpass import getpass

# input api key
# get from https://openai.com/api/
api_key = getpass("Enter your OpenAI API key: ")

#gpt api
gpt_client = OpenAI(api_key=api_key)
# Out:
# Enter your OpenAI API key: ··········

# %%
import numpy as np
import torch

# CLIP Ranking

def clip_image_embed(pil_img, clip_model, clip_preprocess):
    """
    Converts a PIL image into a normalized CLIP image embedding.

    Steps:
    1. Preprocess the image into the format expected by the CLIP model.
    2. Disable gradient calculation for faster inference.
    3. Encode the image using CLIP’s image encoder.
    4. Normalize the resulting embedding vector to unit length.
    """
    # Preprocess image and move it to CPU
    img_in = clip_preprocess(pil_img).unsqueeze(0).to('cpu')

    with torch.no_grad():  # Disable gradients for faster computation
        img_emb = clip_model.encode_image(img_in)
        # Normalize the embedding to prevent magnitude differences from affecting similarity
        return img_emb / img_emb.norm(dim=-1, keepdim=True)


def rank_items_from_embedding(img_emb, text_emb, menu_items, item_pointers):
    """
    Ranks menu items by similarity to an image embedding using CLIP embeddings.

    Args:
        img_emb: Torch tensor representing the image embedding (1 x D).
        text_emb: Torch tensor representing all text embeddings (N x D).
        menu_items: List of menu item names.
        item_pointers: Array mapping text embeddings back to menu item indices.

    Returns:
        A tuple of (sorted_indices, probabilities) where:
        - sorted_indices: Indices of menu_items sorted by descending similarity.
        - probabilities: Normalized softmax-like probabilities per item.
    """
    # Compute cosine similarities between image and all text embeddings
    sims = (img_emb @ text_emb.T).squeeze(0)

    # Initialize array for per-item max similarities
    per_item = np.full(len(menu_items), -1e9, dtype=np.float32)

    # Move tensor to CPU and convert to numpy for easy indexing
    sims_cpu = sims.detach().float().cpu().numpy()

    # For each menu item, store the maximum similarity from its text variants
    for i in range(len(menu_items)):
        per_item[i] = sims_cpu[item_pointers == i].max()

    # Standardize scores (z-score normalization) to stabilize scaling
    z = (per_item - per_item.mean()) / (per_item.std() + 1e-6)

    # Convert standardized scores to probabilities via softmax
    probs = np.exp(z) / np.exp(z).sum()

    # Sort by descending probability
    sorted_indices = np.argsort(-probs)
    sorted_probs = probs[sorted_indices]

    # Return sorted menu indices and corresponding probabilities
    return sorted_indices, sorted_probs

# %%
import base64
from io import BytesIO
import json

from typing import List
from pydantic import BaseModel, confloat

class ClassifiedItem(BaseModel):
    id: int
    name: str
    confidence: confloat(ge=0.0, le=1.0)

class ClassificationResult(BaseModel):
    items: List[ClassifiedItem]   # [{id,name,confidence}, ...]
    explanation: str

def image_to_base64(img):
    """Convert a PIL Image to a base64 data URI for OpenAI API."""
    buffer = BytesIO()
    img.save(buffer, format="JPEG")  # or "PNG" if you prefer
    b64 = base64.b64encode(buffer.getvalue()).decode("utf-8")
    return f"data:image/jpeg;base64,{b64}"

# gpt model 1, item classification
def gpt_item_classification(pil_img, items_ranked, client, model="gpt-5-mini"):
    # convert PIL image to base64
    image_url = image_to_base64(pil_img)

    # pair items with scores (top-N already ranked upstream)
    items_payload = json.dumps(items_ranked)

    # prompt
    prompt_text = (
        "You are a food identification expert specializing in dining hall meals.\n\n"
        "You will be shown an image of a plate and a list of candidate menu items ranked "
        "by visual similarity scores (highest to lowest).\n"
        "Your task: determine which of these items are actually present on the plate.\n\n"
        "Guidelines:\n"
        "- Use both the image and the ranking scores; scores are hints, not ground truth.\n"
        "- Focus only on visible foods; ignore background objects like trays or utensils.\n"
        "- Only choose from the provided menu item list — do not invent new items.\n\n"
        "Output Format (strict JSON):\n"
        '- \"items\": an array of objects, each with fields {\"id\", \"name\", \"confidence\"}\n'
        '- \"confidence\": a float in [0,1] for each chosen item\n'
        '- \"explanation\": a brief 1–2 sentence rationale describing your reasoning.\n'
    )

    # call the gpt responses API
    response = client.responses.parse(
        model=model,
        input=[
            {
                "role": "user",
                "content": [
                    { "type": "input_text", "text": prompt_text },
                    { "type": "input_text", "text": items_payload },
                    { "type": "input_image", "image_url": image_url }
                ],
            }
        ],
        text_format=ClassificationResult
    )

    return response.output_parsed.model_dump()

# %%
from typing import List
from pydantic import BaseModel, confloat

class PortionEstimate(BaseModel):
    id: int
    name: str
    num_servings: confloat(ge=0.0, le=10.0)

class PortionEstimationResult(BaseModel):
    servings: List[PortionEstimate]
    explanation: str

# gpt model 2, portion estimation
def gpt_portion_estimation(pil_img, classification_result, client, model="gpt-5-mini"):
    image_url = image_to_base64(pil_img)
    payload = json.dumps(classification_result, indent=2)

    prompt_text = (
        "You are a nutrition analyst estimating portion sizes.\n\n"
        "INPUTS:\n"
        "1) An image of a single plate.\n"
        "2) A JSON of detected items with nutrition info, including serving size.\n\n"
        "TASK:\n"
        "- For each detected item, output ONLY the number of SERVINGS on the plate, as a decimal if needed.\n"
        "- If serving size uses EACH and shows a number N (e.g., '4 EACH'), then 1 serving = N pieces. "
        "  If you estimate P pieces on the plate, report servings = P / N.\n"
        "- For non-EACH units (g/oz/cup), estimate servings by dividing the visible amount by the serving size.\n"
        "- Do not output the piece count (P). Do not output words like 'tenders' or any free text other than the explanation field.\n"
        "- Do not invent items. Only return items present in the provided JSON.\n"
        "- Include the count in explanation for EACH type items.\n"
        "- If unsure, return your best conservative estimate.\n\n"
        "FORMAT (strict JSON):\n"
        "{\n"
        '  "servings": [ { "id": <int>, "name": "<str>", "estimated_servings": <float> }, ... ],\n'
        '  "explanation": "<1-2 short sentences>"\n'
        "}\n"
    )

    response = client.responses.parse(
        model=model,
        input=[
            {
                "role": "user",
                "content": [
                    {"type": "input_text", "text": prompt_text},
                    {"type": "input_text", "text": payload},
                    {"type": "input_image", "image_url": image_url}
                ]
            }
        ],
        text_format=PortionEstimationResult
    )

    return response.output_parsed.model_dump()

# %%
import open_clip
# Load CLIP model for ranking, use same instance (~6 second on cpu)
model, _, preprocess = open_clip.create_model_and_transforms(
  "ViT-B-32", pretrained="laion2b_s34b_b79k", device='cpu'
)

tokenizer = open_clip.get_tokenizer("ViT-B-32")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# open_clip_model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]

# %%
# api stuff
import requests

def get_menu_items(hallid, meal, date):
    url = "https://husky-eats.onrender.com/api/menu"
    r = requests.get(url, params={"hallid": hallid, "meal": meal, "date": date})
    r.raise_for_status()
    return [
        {"name": item["name"], "id": item["id"]}
        for item in r.json()
        if "name" in item and "id" in item
    ]

def get_nutrition_info(item_id):
    url = "https://husky-eats.onrender.com/api/menuitem/" + str(item_id)
    r = requests.get(url)
    r.raise_for_status()
    return r.json()

# %%
import time
import PIL.Image as Image
import open_clip
import numpy as np

# full pipeline
def predict(pil_image, dining_hall_id, meal, date):
  start_total = time.time()
  print(f"\n=== Running menumatch for new image ({meal}, {date}) ===")

  t0 = time.time()
  print(f"[Loaded image] {time.time() - t0:.3f}s")

  # call huskyeats api for menu items
  t0 = time.time()
  menu_items = get_menu_items(dining_hall_id, meal, date)

  menu_items_names = [item["name"] for item in menu_items]
  print(f"[Loaded menu items] {time.time() - t0:.3f}s")

  clip_prompts = [
    "a photo of {}",
    "a plate of {}",
    "{} on a plate",
    "cafeteria serving of {}",
    "dining hall style {}",
  ]

  t0 = time.time()
  # create prompt variants of each menu item
  item_variants, variant_pointers = [], []
  for idx, item in enumerate(menu_items_names):
    for p in clip_prompts:
      item_variants.append(p.format(item))
      variant_pointers.append(idx)

  variant_pointers = np.array(variant_pointers)
  print(f"[Prepared prompt variants] {time.time() - t0:.3f}s")

  t0 = time.time()
  # generate text embeddings
  # TODO: use redis cache in prod to prevent recomputation of exact same prompts
  text_tokens = tokenizer(item_variants).to('cpu')
  text_emb = model.encode_text(text_tokens)
  text_emb = text_emb / text_emb.norm(dim=-1, keepdim=True)
  print(f"[Generated text embeddings] {time.time() - t0:.3f}s")

  t0 = time.time()
  # embed image
  img_emb = clip_image_embed(pil_image, model, preprocess)
  print(f"[Generated image embedding] {time.time() - t0:.3f}s")

  t0 = time.time()
  # rank text embeddings to image embedding
  items_ranked_idxs, items_scores = rank_items_from_embedding(img_emb, text_emb, menu_items_names, variant_pointers)
  items_ranked = [
    {
        "name": menu_items[i]["name"],
        "id": menu_items[i]["id"],
        "score": float(items_scores[k])
    }
    for k, i in enumerate(items_ranked_idxs)
  ]

  print(f"[CLIP Ranking items] {time.time() - t0:.3f}s")
  print(items_ranked)
  print()

  del text_tokens, text_emb, img_emb

  t0 = time.time()
  # item classification
  classification_result = gpt_item_classification(pil_image, items_ranked, gpt_client)
  print(classification_result)
  print(f"[GPT Item classification] {time.time() - t0:.3f}s")

  # use classification result and pull menu data
  t0 = time.time()
  for item in classification_result["items"]:
    item["nutrition"] = get_nutrition_info(item["id"])
  print(f"[Pulled nutrition info] {time.time() - t0:.3f}s")

  # portion estimation
  t0 = time.time()
  portion_result = gpt_portion_estimation(pil_image, classification_result, gpt_client)
  print(portion_result)
  print(f"[GPT Portion estimation] {time.time() - t0:.3f}s")

  print(f"=== Total runtime: {time.time() - start_total:.3f}s ===\n")
  return portion_result['servings']

# %%
# ---- CONFIG ----
from getpass import getpass

API_BASE_URL = "https://3vw53n9900.execute-api.us-east-1.amazonaws.com/dev"
API_TOKEN = getpass("Enter MenuMatch API token: ")

HUSKYEATS_BASE_URL = "https://husky-eats.onrender.com/api"

# ---- IMPORTS ----
import requests
from dataclasses import dataclass
from typing import List, Optional, Dict, Any, Iterable, Tuple
from io import BytesIO
import math

from PIL import Image


# ---- LOW-LEVEL API HELPERS ----

def _auth_headers() -> Dict[str, str]:
    return {"X-Api-Key": API_TOKEN}


def fetch_dataset_metadata() -> List[Dict[str, Any]]:
    url = f"{API_BASE_URL}/dataset"
    resp = requests.get(url, headers=_auth_headers())
    resp.raise_for_status()
    data = resp.json()
    return data.get("items", data)


def get_download_url(object_key: str, bucket: Optional[str] = None) -> str:
    url = f"{API_BASE_URL}/downloads/presign"
    payload: Dict[str, Any] = {"objectKey": object_key}
    if bucket:
        payload["bucket"] = bucket

    resp = requests.post(url, headers=_auth_headers(), json=payload)
    resp.raise_for_status()
    data = resp.json()
    return data["downloadUrl"]


def load_image(object_key: str, bucket: Optional[str] = None) -> Image.Image:
    download_url = get_download_url(object_key, bucket=bucket)
    resp = requests.get(download_url)
    resp.raise_for_status()
    img = Image.open(BytesIO(resp.content)).convert("RGB")
    return img


def get_nutrition_for_id(menu_item_id):
    # HuskyEats: GET /menuitem/{id}
    url = f"{HUSKYEATS_BASE_URL}/menuitem/{menu_item_id}"
    resp = requests.get(url)
    resp.raise_for_status()
    data = resp.json()

    return {
        "kcal": float(data["calories"]),
        "protein_g": float(data["protein_g"]),
        "carb_g": float(data["totalcarbohydrate_g"]),
        "fat_g": float(data["totalfat_g"]),
    }


# ---- DATA STRUCTURES ----

@dataclass
class GroundTruthItem:
    id: str
    num_servings: float


@dataclass
class Sample:
    object_key: str
    image: Image.Image
    dining_hall_id: str
    meal_time: str
    date: str
    difficulty: Optional[str]
    ground_truth: List[GroundTruthItem]


def iter_samples(limit: Optional[int] = None) -> Iterable[Sample]:
    metadata_items = fetch_dataset_metadata()
    if limit is not None:
        metadata_items = metadata_items[:limit]

    for meta in metadata_items:
        object_key = meta["objectKey"]
        bucket = meta.get("bucket")

        img = load_image(object_key, bucket=bucket)

        gt_items = [
            GroundTruthItem(
                id=str(item["menuItemId"]),
                num_servings=float(item["servings"]),
            )
            for item in meta.get("items", [])
        ]

        yield Sample(
            object_key=object_key,
            image=img,
            dining_hall_id=str(meta.get("diningHallId")),
            meal_time=str(meta.get("mealtime")),
            date=str(meta.get("mealDate")),
            difficulty=meta.get("difficulty"),
            ground_truth=gt_items,
        )


# ---- RUNNER ----

def run_model_on_dataset(
    predict_fn=None,
    limit: Optional[int] = None,
):
    if predict_fn is None:
        try:
            predict_fn = globals()["predict"]
        except KeyError:
            raise ValueError("No predict_fn provided and no global `predict` defined.")

    results = []

    for sample in iter_samples(limit=limit):
        preds = predict_fn(
            sample.image,
            sample.dining_hall_id,
            sample.meal_time,
            sample.date,
        )

        results.append(
            {
                "object_key": sample.object_key,
                "dining_hall_id": sample.dining_hall_id,
                "meal_time": sample.meal_time,
                "date": sample.date,
                "ground_truth": sample.ground_truth,
                "predictions": preds,
            }
        )

    return results


# ---- METRICS ----

def _items_to_dict(items: Iterable[Any]) -> Dict[str, float]:
    out: Dict[str, float] = {}
    for it in items:
        if hasattr(it, "id"):
            _id = str(it.id)
            servings = float(it.num_servings)
        else:
            _id = str(it["id"])
            servings = float(it.get("num_servings", 0.0))
        out[_id] = servings
    return out


def compute_all_metrics(
    results: List[Dict[str, Any]],
    get_nutrition_for_id: Optional[callable] = None,
    macro_nutrients: Tuple[str, ...] = ("kcal", "protein_g", "carb_g", "fat_g"),
) -> Dict[str, float]:
    tp = fp = fn = 0
    jaccards: List[float] = []
    exact_match_count = 0

    abs_errors: List[float] = []
    sq_errors: List[float] = []
    perc_errors: List[float] = []

    for r in results:
        gt = _items_to_dict(r["ground_truth"])
        pr = _items_to_dict(r["predictions"])

        gt_ids = {k for k, v in gt.items() if v > 0}
        pr_ids = {k for k, v in pr.items() if v > 0}

        inter = gt_ids & pr_ids
        tp += len(inter)
        fp += len(pr_ids - gt_ids)
        fn += len(gt_ids - pr_ids)

        union = gt_ids | pr_ids
        j = len(inter) / len(union) if union else 1.0
        jaccards.append(j)

        if gt_ids == pr_ids:
            exact_match_count += 1

        all_ids = set(gt.keys()) | set(pr.keys())
        for item_id in all_ids:
            g = gt.get(item_id, 0.0)
            p = pr.get(item_id, 0.0)
            err = p - g
            ae = abs(err)
            abs_errors.append(ae)
            sq_errors.append(err * err)
            if g > 0:
                perc_errors.append(ae / g)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0

    avg_jaccard = sum(jaccards) / len(jaccards) if jaccards else 0.0
    exact_match = exact_match_count / len(results) if results else 0.0

    mae_serv = sum(abs_errors) / len(abs_errors) if abs_errors else 0.0
    rmse_serv = math.sqrt(sum(sq_errors) / len(sq_errors)) if sq_errors else 0.0
    pmae_serv = sum(perc_errors) / len(perc_errors) if perc_errors else 0.0

    metrics: Dict[str, float] = {
        "cls_precision": precision,
        "cls_recall": recall,
        "cls_f1": f1,
        "cls_avg_jaccard": avg_jaccard,
        "cls_exact_match": exact_match,
        "portion_mae_servings": mae_serv,
        "portion_rmse_servings": rmse_serv,
        "portion_pmae_servings": pmae_serv,
    }

    if get_nutrition_for_id is not None:
        nutr_cache: Dict[str, Dict[str, float]] = {}

        def nutr(item_id: str) -> Dict[str, float]:
            if item_id not in nutr_cache:
                nutr_cache[item_id] = get_nutrition_for_id(item_id)
            return nutr_cache[item_id]

        macro_abs_errors = {n: [] for n in macro_nutrients}
        macro_perc_errors = {n: [] for n in macro_nutrients}

        for r in results:
            gt = _items_to_dict(r["ground_truth"])
            pr = _items_to_dict(r["predictions"])

            gt_tot = {n: 0.0 for n in macro_nutrients}
            pr_tot = {n: 0.0 for n in macro_nutrients}

            for item_id, servings in gt.items():
                info = nutr(item_id)
                for n in macro_nutrients:
                    gt_tot[n] += servings * float(info[n])

            for item_id, servings in pr.items():
                info = nutr(item_id)
                for n in macro_nutrients:
                    pr_tot[n] += servings * float(info[n])

            for n in macro_nutrients:
                g = gt_tot[n]
                p = pr_tot[n]
                ae = abs(p - g)
                macro_abs_errors[n].append(ae)
                if g > 0:
                    macro_perc_errors[n].append(ae / g)

        for n in macro_nutrients:
            ae_list = macro_abs_errors[n]
            pe_list = macro_perc_errors[n]

            metrics[f"macro_mae_{n}"] = sum(ae_list) / len(ae_list) if ae_list else 0.0
            metrics[f"macro_pmae_{n}"] = sum(pe_list) / len(pe_list) if pe_list else 0.0

    return metrics


# ---- TEMPLATE PREDICT FUNCTION (DELETE/EDIT IN EACH NOTEBOOK) ----
# def predict(image, dining_hall_id, meal_time, date):
#     return []
# Out:
# Enter MenuMatch API token: ··········

# %%
results = run_model_on_dataset(limit=30)
metrics = compute_all_metrics(results, get_nutrition_for_id=get_nutrition_for_id)

for k, v in metrics.items():
    print(f"{k:25s} {v:.4f}")
# Out:
# === Running menumatch for new image (dinner, 2025-10-22) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.330s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 6.600s
# [Generated image embedding] 0.288s
# [CLIP Ranking items] 0.009s
# [{'name': "General Tso's Chicken", 'id': 111083, 'score': 0.3230091631412506}, {'name': 'Shrimp Egg Foo Yung', 'id': 300656, 'score': 0.2066836804151535}, {'name': 'Jasmine Rice', 'id': 400711, 'score': 0.1253126710653305}, {'name': 'Veggie Strip Stir Fry', 'id': 300685, 'score': 0.06751075387001038}, {'name': 'Crinkle Cut Fries', 'id': 161028, 'score': 0.040266264230012894}, {'name': 'Fortune Cookies', 'id': 601156, 'score': 0.03612662851810455}, {'name': 'Chefs Choice Lo Mein', 'id': 142046, 'score': 0.03413303568959236}, {'name': 'Summer Vegetable Medley', 'id': 300974, 'score': 0.031123332679271698}, {'name': 'Mini Vegetable Egg Rolls', 'id': 142220, 'score': 0.029234956949949265}, {'name': 'Corn & Bacon Chowder', 'id': 300876, 'score': 0.022185103967785835}, {'name': 'Three Cheese Bread', 'id': 811018, 'score': 0.019034532830119133}, {'name': 'Cannoli', 'id': 889071, 'score': 0.016087191179394722}, {'name': 'Baked Ziti', 'id': 141091, 'score': 0.015265868045389652}, {'name': 'Spaghetti', 'id': 165001, 'score': 0.013468313030898571}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.010416355915367603}, {'name': 'Beef Cheeseburger w/ Bun', 'id': 73008, 'score': 0.010142172686755657}]
#
# {'items': [{'id': 111083, 'name': "General Tso's Chicken", 'confidence': 0.92}, {'id': 400711, 'name': 'Jasmine Rice', 'confidence': 0.88}], 'explanation': "The plate clearly shows breaded, sauced orange-brown pieces with small broccoli florets consistent with General Tso's chicken, alongside a portion of white, long-grain rice that matches jasmine rice."}
# [GPT Item classification] 8.513s
# [Pulled nutrition info] 0.471s
# {'servings': [{'id': 111083, 'name': "General Tso's Chicken", 'num_servings': 1.0}, {'id': 400711, 'name': 'Jasmine Rice', 'num_servings': 1.5}], 'explanation': "Estimated ~1.0 serving of General Tso's Chicken and ~1.5 servings of Jasmine Rice based on visual portion sizes (chicken ≈ one 8 oz serving; rice ≈ 4.5 oz)."}
# [GPT Portion estimation] 14.680s
# === Total runtime: 31.004s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-29) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.148s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 10.188s
# [Generated image embedding] 0.215s
# [CLIP Ranking items] 0.001s
# [{'name': 'Chocolate Chip Delight', 'id': 882068, 'score': 0.16080427169799805}, {'name': 'Baked Beans', 'id': 141059, 'score': 0.15481501817703247}, {'name': 'Macaroni & Cheese', 'id': 131007, 'score': 0.09500308334827423}, {'name': 'Halal Beef Lasagna', 'id': 142035, 'score': 0.062188878655433655}, {'name': 'Vegan BBQ Beef', 'id': 400403, 'score': 0.049175046384334564}, {'name': 'BBQ Sauce', 'id': 200755, 'score': 0.048091206699609756}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.042130354791879654}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.03887607157230377}, {'name': 'Green Beans', 'id': 401002, 'score': 0.036978866904973984}, {'name': 'White Rice', 'id': 163002, 'score': 0.03380269929766655}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.03073187917470932}, {'name': 'Crinkle Cut Fries', 'id': 161028, 'score': 0.02970895916223526}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.02825918421149254}, {'name': 'Corn Cobettes', 'id': 171040, 'score': 0.02581648901104927}, {'name': 'Pulled Pork', 'id': 300744, 'score': 0.02397925965487957}, {'name': 'Tempura Battered Pickle Chips', 'id': 121006, 'score': 0.02185298129916191}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.016161741688847542}, {'name': 'Snickerdoodle Cookies', 'id': 882014, 'score': 0.015961848199367523}, {'name': 'Sauteed Baby Bok Choy', 'id': 302228, 'score': 0.015298892743885517}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.013187292963266373}, {'name': 'Malibu Veggie Burger w/ Bun', 'id': 142183, 'score': 0.011214741505682468}, {'name': 'Herbed Garlic Bread', 'id': 299911, 'score': 0.010332309640944004}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.00898746121674776}, {'name': 'Kielbasa Dogs', 'id': 85021, 'score': 0.006647699978202581}, {'name': 'Orange Chicken Stir Fry', 'id': 111142, 'score': 0.00639038160443306}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.006165549624711275}, {'name': 'Collard Greens with Applewood Bacon', 'id': 300730, 'score': 0.005170448217540979}, {'name': 'Singapore Street Noodles with Shrimp', 'id': 300884, 'score': 0.0022672959603369236}]
#
# {'items': [{'id': 141059, 'name': 'Baked Beans', 'confidence': 0.96}], 'explanation': 'The plate clearly shows small brown beans in a glossy brown sauce consistent with baked beans; no other menu items are visible in the image.'}
# [GPT Item classification] 5.253s
# [Pulled nutrition info] 0.129s
# {'servings': [{'id': 141059, 'name': 'Baked Beans', 'num_servings': 0.3}], 'explanation': 'Plate shows a small spoonful (~1 oz / ~30 g) of baked beans compared to a 4 oz serving, so about 0.3 servings.'}
# [GPT Portion estimation] 18.712s
# === Total runtime: 34.927s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-23) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.145s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 10.269s
# [Generated image embedding] 0.166s
# [CLIP Ranking items] 0.001s
# [{'name': 'Straight Cut French Fries', 'id': 161038, 'score': 0.4941120743751526}, {'name': 'Green Beans', 'id': 401002, 'score': 0.05182819440960884}, {'name': 'Herb Buttered Corn', 'id': 300690, 'score': 0.048020731657743454}, {'name': 'Lemon Dill Fish of the Day', 'id': 302997, 'score': 0.046229489147663116}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.033368129283189774}, {'name': 'Grilled Guinness Bratwurst', 'id': 11701, 'score': 0.029201800003647804}, {'name': 'Sauteed Baby Bok Choy', 'id': 302228, 'score': 0.029014870524406433}, {'name': 'Mashed Potatoes', 'id': 161011, 'score': 0.026842940598726273}, {'name': 'Halal Teriyaki Beef Tips', 'id': 400996, 'score': 0.023579884320497513}, {'name': 'Brown Chicken Gravy', 'id': 400939, 'score': 0.021281378343701363}, {'name': 'Macaroni & Cheese', 'id': 131007, 'score': 0.020746277645230293}, {'name': 'Curry Tofu', 'id': 302289, 'score': 0.019451260566711426}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.017160581424832344}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.015636572614312172}, {'name': 'Baked Sesame Nuggets', 'id': 141151, 'score': 0.013866446912288666}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.01361805945634842}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.013352976180613041}, {'name': 'Basmati Rice', 'id': 299916, 'score': 0.012310972437262535}, {'name': 'Thai Yellow Rice', 'id': 302599, 'score': 0.01143259834498167}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.0108613520860672}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.009092601016163826}, {'name': 'Chicken Popcorn Bites', 'id': 111097, 'score': 0.008748235180974007}, {'name': 'Japanese Curry Chicken', 'id': 400744, 'score': 0.007188295945525169}, {'name': 'Chocolate Brownies', 'id': 889034, 'score': 0.006629365496337414}, {'name': 'Red Velvet Cookie', 'id': 882012, 'score': 0.0061035798862576485}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.004098016303032637}, {'name': 'Beet and Kale Burger w/ Bun', 'id': 142187, 'score': 0.0031478572636842728}, {'name': 'Buffalo Cauliflower', 'id': 302951, 'score': 0.0030754648614674807}]
#
# {'items': [{'id': 161038, 'name': 'Straight Cut French Fries', 'confidence': 0.95}], 'explanation': 'The plate clearly contains golden, straight-cut potato fries with skin on some pieces, matching Straight Cut French Fries; no other menu items are visible.'}
# [GPT Item classification] 4.780s
# [Pulled nutrition info] 0.149s
# {'servings': [{'id': 161038, 'name': 'Straight Cut French Fries', 'num_servings': 0.5}], 'explanation': 'I estimate roughly half of a 4 oz serving of fries on the plate based on the visible amount.'}
# [GPT Portion estimation] 9.568s
# === Total runtime: 25.247s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-31) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.140s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 9.145s
# [Generated image embedding] 0.151s
# [CLIP Ranking items] 0.001s
# [{'name': 'Fried Chicken Nuggets', 'id': 111037, 'score': 0.2074747085571289}, {'name': 'Cross Trax French Fries', 'id': 161069, 'score': 0.16292083263397217}, {'name': 'Corn', 'id': 171012, 'score': 0.1143399327993393}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.05748386308550835}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.05454554408788681}, {'name': 'Baked Sesame Nuggets', 'id': 141151, 'score': 0.05310562625527382}, {'name': 'Panko Crusted Fish of the Day', 'id': 121049, 'score': 0.04499173164367676}, {'name': 'Bacon Cheddar Mashed Potatoes', 'id': 400915, 'score': 0.03392837196588516}, {'name': 'M & M Cookies', 'id': 882024, 'score': 0.03097335621714592}, {'name': 'Chefs Choice Fried Rice', 'id': 202001, 'score': 0.028563372790813446}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.028016068041324615}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.02249748259782791}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.021966993808746338}, {'name': 'Chefs Choice Lo Mein', 'id': 142046, 'score': 0.019638696685433388}, {'name': 'Sweet Potato Black Bean Burger with Bun', 'id': 142210, 'score': 0.017364440485835075}, {'name': 'Edamame Dumpling', 'id': 302575, 'score': 0.01653904840350151}, {'name': 'Halal Chicken Fajita', 'id': 299909, 'score': 0.01387531403452158}, {'name': 'Rice Florentine', 'id': 163036, 'score': 0.013023201376199722}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.01264986488968134}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.011990812607109547}, {'name': 'Raspberry Cheese Bar', 'id': 889063, 'score': 0.009342232719063759}, {'name': 'Sauteed Brussels Sprouts', 'id': 400832, 'score': 0.008203940466046333}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.008195588365197182}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.005274621304124594}, {'name': 'Beef and Broccoli Stir Fry', 'id': 300014, 'score': 0.0030943488236516714}]
#
# {'items': [{'id': 111037, 'name': 'Fried Chicken Nuggets', 'confidence': 0.97}, {'id': 161069, 'name': 'Cross Trax French Fries', 'confidence': 0.92}, {'id': 171012, 'name': 'Corn', 'confidence': 0.9}], 'explanation': 'The plate clearly shows multiple breaded, round chicken nuggets, waffle/ lattice-cut fries (Cross Trax style), and a pile of yellow corn kernels, matching those menu items visually.'}
# [GPT Item classification] 6.034s
# [Pulled nutrition info] 0.409s
# {'servings': [{'id': 111037, 'name': 'Fried Chicken Nuggets', 'num_servings': 1.67}, {'id': 161069, 'name': 'Cross Trax French Fries', 'num_servings': 1.25}, {'id': 171012, 'name': 'Corn', 'num_servings': 0.83}], 'explanation': 'I counted about 10 chicken nuggets on the plate (10 pieces → 1.67 servings). Fries estimated ~5 oz (≈1.25 servings) and corn ~2.5 oz (≈0.83 servings).'}
# [GPT Portion estimation] 15.335s
# === Total runtime: 31.298s ===
#
#
# === Running menumatch for new image (lunch, 2025-11-03) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.306s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 9.733s
# [Generated image embedding] 0.227s
# [CLIP Ranking items] 0.002s
# [{'name': 'Halal Cajun Chicken', 'id': 300489, 'score': 0.11524881422519684}, {'name': 'Fried Cabbage', 'id': 304027, 'score': 0.10690147429704666}, {'name': 'Macaroni & Cheese', 'id': 200692, 'score': 0.06853710114955902}, {'name': 'Roasted Chicken', 'id': 200396, 'score': 0.06848988682031631}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.06110573932528496}, {'name': 'Bacon Crumbles', 'id': 200318, 'score': 0.05951368808746338}, {'name': 'Roasted Potato Medley', 'id': 299918, 'score': 0.05102841928601265}, {'name': 'Herb Grilled Tofu', 'id': 400895, 'score': 0.04921327158808708}, {'name': 'Cheddar Beer Cheese', 'id': 302822, 'score': 0.04903445765376091}, {'name': 'Jalapenos', 'id': 200305, 'score': 0.04829675331711769}, {'name': 'Steamed Broccoli', 'id': 200425, 'score': 0.04102429002523422}, {'name': 'Potato & Cheese Pierogi', 'id': 300737, 'score': 0.039562635123729706}, {'name': 'Beyond Meat Beef Strips', 'id': 142190, 'score': 0.027754228562116623}, {'name': 'Beyond Burger', 'id': 142188, 'score': 0.026234600692987442}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.025595299899578094}, {'name': 'Buffalo Sauce', 'id': 200602, 'score': 0.024721862748265266}, {'name': 'Summer Vegetable Medley', 'id': 300974, 'score': 0.020178811624646187}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.018314220011234283}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.01632765308022499}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.016185997053980827}, {'name': 'Curly Fries', 'id': 161027, 'score': 0.014985158108174801}, {'name': 'Kielbasa', 'id': 85022, 'score': 0.010111697018146515}, {'name': 'Pumpkin Spice Blondies', 'id': 889035, 'score': 0.00813201256096363}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.008090595714747906}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.006560773588716984}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.006511416751891375}, {'name': 'Red ,White & Blue Cookies', 'id': 882063, 'score': 0.006396304816007614}, {'name': 'Soft Pretzel', 'id': 12020, 'score': 0.0035631447099149227}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.002379773184657097}]
#
# {'items': [{'id': 111027, 'name': 'Grilled Chicken Breast', 'confidence': 0.9}, {'id': 200692, 'name': 'Macaroni & Cheese', 'confidence': 0.88}, {'id': 200425, 'name': 'Steamed Broccoli', 'confidence': 0.75}], 'explanation': 'The plate clearly shows chopped/sliced white chicken with grill/char marks (grilled chicken breast), a baked mac-and-cheese with breadcrumb topping on the right, and a few steamed broccoli florets at the bottom. Visual appearance matches these menu items.'}
# [GPT Item classification] 12.154s
# [Pulled nutrition info] 0.613s
# {'servings': [{'id': 111027, 'name': 'Grilled Chicken Breast', 'num_servings': 1.0}, {'id': 200692, 'name': 'Macaroni & Cheese', 'num_servings': 1.5}, {'id': 200425, 'name': 'Steamed Broccoli', 'num_servings': 0.5}], 'explanation': 'Estimated 1 piece of grilled chicken (1.0 serving). Mac & cheese about 9 oz (~1.5 servings) and broccoli roughly 1 oz (~0.5 serving).'}
# [GPT Portion estimation] 20.236s
# === Total runtime: 43.473s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-24) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.146s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 8.251s
# [Generated image embedding] 0.147s
# [CLIP Ranking items] 0.001s
# [{'name': 'Pernil', 'id': 300016, 'score': 0.24170167744159698}, {'name': 'Yellow Rice with Pigeon Peas', 'id': 163010, 'score': 0.12801231443881989}, {'name': 'Fajita Bar', 'id': 200092, 'score': 0.0953141301870346}, {'name': 'Basmati Rice', 'id': 299916, 'score': 0.07400830835103989}, {'name': 'Halal Mongolian Beef', 'id': 300499, 'score': 0.06428562849760056}, {'name': 'Cross Trax French Fries', 'id': 161069, 'score': 0.053446829319000244}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.04221741855144501}, {'name': 'Lime Infused Swordfish', 'id': 121054, 'score': 0.033967483788728714}, {'name': 'Yucca Fries', 'id': 161025, 'score': 0.03358825668692589}, {'name': 'Halal Baby Carrots', 'id': 401007, 'score': 0.03012063540518284}, {'name': 'Black Beans In Sofrito', 'id': 302435, 'score': 0.027436766773462296}, {'name': 'Baked Plantains', 'id': 160999, 'score': 0.02103319577872753}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.020271997898817062}, {'name': 'Grilled Pineapple', 'id': 300090, 'score': 0.019613778218626976}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.019535690546035767}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.016088513657450676}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.013624073006212711}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.012037159875035286}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.01087565254420042}, {'name': 'Apple Cheesecake Bar', 'id': 886055, 'score': 0.010804504156112671}, {'name': 'Sauteed Spinach With Garlic', 'id': 302995, 'score': 0.008688479661941528}, {'name': 'Chocolate Drizzled Macaroons', 'id': 882025, 'score': 0.006742408033460379}, {'name': 'Sweet Potato Black Bean Burger with Bun', 'id': 142210, 'score': 0.005778018850833178}, {'name': 'Cinnamon Sugared Churros', 'id': 400963, 'score': 0.005689495708793402}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.005117575637996197}]
#
# {'items': [{'id': 300016, 'name': 'Pernil', 'confidence': 0.92}, {'id': 163010, 'name': 'Yellow Rice with Pigeon Peas', 'confidence': 0.88}], 'explanation': 'The plate shows shredded, roasted pork consistent with pernil and a portion of seasoned yellow rice with visible small peas/beans mixed in, matching yellow rice with pigeon peas.'}
# [GPT Item classification] 6.206s
# [Pulled nutrition info] 0.276s
# {'servings': [{'id': 300016, 'name': 'Pernil', 'num_servings': 1.5}, {'id': 163010, 'name': 'Yellow Rice with Pigeon Peas', 'num_servings': 1.5}], 'explanation': 'About 6 oz of pernil (~1.5 servings of 4 oz) and about 4.5 oz of yellow rice with pigeon peas (~1.5 servings of 3 oz).'}
# [GPT Portion estimation] 15.895s
# === Total runtime: 31.062s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-21) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.142s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 5.905s
# [Generated image embedding] 0.148s
# [CLIP Ranking items] 0.000s
# [{'name': 'Crinkle Cut Fries', 'id': 161028, 'score': 0.375706285238266}, {'name': 'Penne Pasta', 'id': 165019, 'score': 0.2251848727464676}, {'name': 'Parmesan Cream Sauce', 'id': 300722, 'score': 0.0697086825966835}, {'name': 'Soy Dipping Sauce', 'id': 400909, 'score': 0.05971657484769821}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.038978252559900284}, {'name': 'Crispy Orange Ginger Tofu', 'id': 300836, 'score': 0.027007749304175377}, {'name': 'Scallion Pancakes', 'id': 300882, 'score': 0.02577880769968033}, {'name': 'French Onion Focaccia', 'id': 811029, 'score': 0.02559642307460308}, {'name': 'Grilled Hot Dogs w/ Toasted Roll', 'id': 77003, 'score': 0.025149941444396973}, {'name': 'Cocoa Krispie Bar', 'id': 889037, 'score': 0.024864548817276955}, {'name': 'Mini Beef Meatballs', 'id': 153046, 'score': 0.023848315700888634}, {'name': 'Sugar Cookies', 'id': 882004, 'score': 0.021673938259482384}, {'name': 'Kimchi Fried Rice', 'id': 302986, 'score': 0.01395009458065033}, {'name': 'Steamed Pork and Cabbage Dumplings', 'id': 161089, 'score': 0.013191410340368748}, {'name': 'Steamed Broccoli', 'id': 175014, 'score': 0.01112678274512291}, {'name': 'Korean BBQ Chicken', 'id': 300697, 'score': 0.009397302754223347}, {'name': 'Malibu Veggie Burger w/ Bun', 'id': 142183, 'score': 0.009120021015405655}]
#
# {'items': [{'id': 161028, 'name': 'Crinkle Cut Fries', 'confidence': 0.98}], 'explanation': 'The plate clearly contains golden, ridged crinkle-cut fries and no other visible menu items from the provided list are present.'}
# [GPT Item classification] 5.227s
# [Pulled nutrition info] 0.320s
# {'servings': [{'id': 161028, 'name': 'Crinkle Cut Fries', 'num_servings': 1.25}], 'explanation': 'Plate appears to hold about 5 oz of crinkle-cut fries, roughly 1.25 servings (serving size 4 oz).'}
# [GPT Portion estimation] 10.551s
# === Total runtime: 22.389s ===
#
#
# === Running menumatch for new image (lunch, 2025-11-03) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.163s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 10.035s
# [Generated image embedding] 0.151s
# [CLIP Ranking items] 0.001s
# [{'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.12577927112579346}, {'name': 'Herb Grilled Tofu', 'id': 400895, 'score': 0.08700397610664368}, {'name': 'Potato & Cheese Pierogi', 'id': 300737, 'score': 0.07869812846183777}, {'name': 'Roasted Chicken', 'id': 200396, 'score': 0.0726044774055481}, {'name': 'Fried Cabbage', 'id': 304027, 'score': 0.07218293100595474}, {'name': 'Halal Cajun Chicken', 'id': 300489, 'score': 0.07153302431106567}, {'name': 'Roasted Potato Medley', 'id': 299918, 'score': 0.06639746576547623}, {'name': 'Bacon Crumbles', 'id': 200318, 'score': 0.05586942657828331}, {'name': 'Macaroni & Cheese', 'id': 200692, 'score': 0.05297533795237541}, {'name': 'Jalapenos', 'id': 200305, 'score': 0.041686564683914185}, {'name': 'Beyond Meat Beef Strips', 'id': 142190, 'score': 0.036169376224279404}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.02755865827202797}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.025638574734330177}, {'name': 'Cheddar Beer Cheese', 'id': 302822, 'score': 0.022723879665136337}, {'name': 'Curly Fries', 'id': 161027, 'score': 0.0208523441106081}, {'name': 'Buffalo Sauce', 'id': 200602, 'score': 0.019335119053721428}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.016802391037344933}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.01465006172657013}, {'name': 'Kielbasa', 'id': 85022, 'score': 0.01451499480754137}, {'name': 'Soft Pretzel', 'id': 12020, 'score': 0.011840591207146645}, {'name': 'Summer Vegetable Medley', 'id': 300974, 'score': 0.01086774468421936}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.008635112084448338}, {'name': 'Steamed Broccoli', 'id': 200425, 'score': 0.008064517751336098}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.007890981622040272}, {'name': 'Pumpkin Spice Blondies', 'id': 889035, 'score': 0.007763769011944532}, {'name': 'Beyond Burger', 'id': 142188, 'score': 0.007637819275259972}, {'name': 'Red ,White & Blue Cookies', 'id': 882063, 'score': 0.007546728476881981}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.003640010254457593}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.003136725164949894}]
#
# {'items': [{'id': 111027, 'name': 'Grilled Chicken Breast', 'confidence': 0.92}], 'explanation': 'The plate contains bite-sized pieces of white, lean, lightly seared poultry with grill/roast marks and texture consistent with sliced grilled chicken breast; no other menu items are visible.'}
# [GPT Item classification] 5.973s
# [Pulled nutrition info] 0.334s
# {'servings': [{'id': 111027, 'name': 'Grilled Chicken Breast', 'num_servings': 1.0}], 'explanation': 'Estimated 1 whole piece (about 8–12 cut pieces) on the plate; counted fragments total roughly one breast, so 1 serving.'}
# [GPT Portion estimation] 18.226s
# === Total runtime: 35.069s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-27) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.151s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 9.024s
# [Generated image embedding] 0.212s
# [CLIP Ranking items] 0.001s
# [{'name': 'Zesty Fried Chicken Tenders', 'id': 111012, 'score': 0.26525625586509705}, {'name': 'Curly Fries', 'id': 161027, 'score': 0.09356396645307541}, {'name': 'Halal Chicken Nugget', 'id': 401028, 'score': 0.07108835875988007}, {'name': 'Country Gravy', 'id': 151001, 'score': 0.06742499023675919}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.05738723650574684}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.05019407346844673}, {'name': 'Beyond Burger', 'id': 142188, 'score': 0.0470556765794754}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.04596756398677826}, {'name': 'Garlic Breadsticks', 'id': 303204, 'score': 0.03595495969057083}, {'name': 'Chicken Noodle Soup', 'id': 23002, 'score': 0.031460683792829514}, {'name': 'Herb Buttered Corn', 'id': 300690, 'score': 0.02740788459777832}, {'name': 'Roasted Green Beans', 'id': 302989, 'score': 0.02266228199005127}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.02231966145336628}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.02079518511891365}, {'name': 'Halal Baby Carrots', 'id': 401007, 'score': 0.020635323598980904}, {'name': 'Cheddar Mashed Potatoes', 'id': 161023, 'score': 0.02046300284564495}, {'name': 'Cajun Salmon W/ Honey Dill Mustard Sauce', 'id': 125025, 'score': 0.014258249662816525}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.014141715131700039}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.012110769748687744}, {'name': 'Raspberry Streusel Bar', 'id': 882045, 'score': 0.011646108701825142}, {'name': 'Mashed Red Potatoes with Garlic', 'id': 300575, 'score': 0.011014033108949661}, {'name': 'Double Chocolate Chip Cookie', 'id': 882019, 'score': 0.008692665956914425}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.00791595783084631}, {'name': 'Minestrone Soup', 'id': 410402, 'score': 0.007404135074466467}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.005166050978004932}, {'name': 'Cheddar Broccoli Soup', 'id': 400931, 'score': 0.004948855843394995}, {'name': 'Chickpea & Kale Stew', 'id': 410492, 'score': 0.0030643215868622065}]
#
# {'items': [{'id': 111012, 'name': 'Zesty Fried Chicken Tenders', 'confidence': 0.95}, {'id': 161027, 'name': 'Curly Fries', 'confidence': 0.92}, {'id': 303204, 'name': 'Garlic Breadsticks', 'confidence': 0.88}], 'explanation': 'The plate clearly shows two battered fried chicken strips consistent with chicken tenders, a pile of spiral/curly fries, and a toasted long breadstick that matches garlic breadsticks in appearance.'}
# [GPT Item classification] 7.647s
# [Pulled nutrition info] 0.740s
# {'servings': [{'id': 111012, 'name': 'Zesty Fried Chicken Tenders', 'num_servings': 0.5}, {'id': 161027, 'name': 'Curly Fries', 'num_servings': 1.0}, {'id': 303204, 'name': 'Garlic Breadsticks', 'num_servings': 1.0}], 'explanation': 'I count 2 chicken pieces (2/4 each = 0.5 servings), roughly 1 serving (~4 oz) of curly fries, and 1 garlic breadstick (1/1 each = 1.0 serving).'}
# [GPT Portion estimation] 13.015s
# === Total runtime: 31.075s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-27) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.335s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 10.282s
# [Generated image embedding] 0.166s
# [CLIP Ranking items] 0.001s
# [{'name': 'Cheddar Mashed Potatoes', 'id': 161023, 'score': 0.27155670523643494}, {'name': 'Country Gravy', 'id': 151001, 'score': 0.11227679252624512}, {'name': 'Herb Buttered Corn', 'id': 300690, 'score': 0.08082951605319977}, {'name': 'Mashed Red Potatoes with Garlic', 'id': 300575, 'score': 0.07589833438396454}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.04446251690387726}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.0419369600713253}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.032738007605075836}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.031600914895534515}, {'name': 'Cheddar Broccoli Soup', 'id': 400931, 'score': 0.031041227281093597}, {'name': 'Beyond Burger', 'id': 142188, 'score': 0.030878428369760513}, {'name': 'Halal Baby Carrots', 'id': 401007, 'score': 0.029197702184319496}, {'name': 'Cajun Salmon W/ Honey Dill Mustard Sauce', 'id': 125025, 'score': 0.026355916634202003}, {'name': 'Chicken Noodle Soup', 'id': 23002, 'score': 0.02394392341375351}, {'name': 'Garlic Breadsticks', 'id': 303204, 'score': 0.022613227367401123}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.020299287512898445}, {'name': 'Halal Chicken Nugget', 'id': 401028, 'score': 0.019976602867245674}, {'name': 'Curly Fries', 'id': 161027, 'score': 0.01572137139737606}, {'name': 'Double Chocolate Chip Cookie', 'id': 882019, 'score': 0.015611579641699791}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.015385080128908157}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.013155970722436905}, {'name': 'Zesty Fried Chicken Tenders', 'id': 111012, 'score': 0.011231969110667706}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.00805212277919054}, {'name': 'Raspberry Streusel Bar', 'id': 882045, 'score': 0.006170148029923439}, {'name': 'Roasted Green Beans', 'id': 302989, 'score': 0.005572176538407803}, {'name': 'Minestrone Soup', 'id': 410402, 'score': 0.005252061411738396}, {'name': 'Chickpea & Kale Stew', 'id': 410492, 'score': 0.004174777306616306}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.0040666768327355385}]
#
# {'items': [{'id': 161023, 'name': 'Cheddar Mashed Potatoes', 'confidence': 0.88}], 'explanation': 'The plate shows a creamy, smooth mashed-potato portion with pepper flecks and the texture/appearance matching mashed potatoes; the top visual-match (Cheddar Mashed Potatoes) is the best fit.'}
# [GPT Item classification] 7.229s
# [Pulled nutrition info] 0.133s
# {'servings': [{'id': 161023, 'name': 'Cheddar Mashed Potatoes', 'num_servings': 0.6}], 'explanation': 'Visual volume compared to a 4 oz serving; the remaining portion appears to be about 60% of a full 4 oz serving.'}
# [GPT Portion estimation] 8.773s
# === Total runtime: 27.104s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-31) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.143s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 8.989s
# [Generated image embedding] 0.147s
# [CLIP Ranking items] 0.000s
# [{'name': 'Fried Chicken Nuggets', 'id': 111037, 'score': 0.29597243666648865}, {'name': 'Baked Sesame Nuggets', 'id': 141151, 'score': 0.16916103661060333}, {'name': 'Edamame Dumpling', 'id': 302575, 'score': 0.05725114420056343}, {'name': 'M & M Cookies', 'id': 882024, 'score': 0.0515194833278656}, {'name': 'Panko Crusted Fish of the Day', 'id': 121049, 'score': 0.049476660788059235}, {'name': 'Cross Trax French Fries', 'id': 161069, 'score': 0.04933694750070572}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.037521298974752426}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.0354609452188015}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.03177715092897415}, {'name': 'Rice Florentine', 'id': 163036, 'score': 0.025029227137565613}, {'name': 'Sauteed Brussels Sprouts', 'id': 400832, 'score': 0.02343829534947872}, {'name': 'Corn', 'id': 171012, 'score': 0.023352356627583504}, {'name': 'Bacon Cheddar Mashed Potatoes', 'id': 400915, 'score': 0.022960945963859558}, {'name': 'Sweet Potato Black Bean Burger with Bun', 'id': 142210, 'score': 0.02169107273221016}, {'name': 'Halal Chicken Fajita', 'id': 299909, 'score': 0.013860952109098434}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.013243724592030048}, {'name': 'Raspberry Cheese Bar', 'id': 889063, 'score': 0.012112135998904705}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.012069180607795715}, {'name': 'Chefs Choice Fried Rice', 'id': 202001, 'score': 0.011495913378894329}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.01099711935967207}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.0094865458086133}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.006742128171026707}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.0066641466692090034}, {'name': 'Chefs Choice Lo Mein', 'id': 142046, 'score': 0.0051936800591647625}, {'name': 'Beef and Broccoli Stir Fry', 'id': 300014, 'score': 0.004185461904853582}]
#
# {'items': [{'id': 111037, 'name': 'Fried Chicken Nuggets', 'confidence': 0.92}], 'explanation': 'The plate shows multiple small, breaded, golden-brown pieces with the typical shape and texture of fried chicken nuggets; no other menu items (fries, pizza, or dumplings) are visible.'}
# [GPT Item classification] 5.263s
# [Pulled nutrition info] 0.133s
# {'servings': [{'id': 111037, 'name': 'Fried Chicken Nuggets', 'num_servings': 1.67}], 'explanation': 'I count 10 pieces on the plate; with a serving defined as 6 EACH, 10/6 ≈ 1.67 servings.'}
# [GPT Portion estimation] 11.528s
# === Total runtime: 26.347s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-31) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.134s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 8.995s
# [Generated image embedding] 0.145s
# [CLIP Ranking items] 0.001s
# [{'name': 'Corn', 'id': 171012, 'score': 0.49123358726501465}, {'name': 'Cross Trax French Fries', 'id': 161069, 'score': 0.05515548586845398}, {'name': 'Edamame Dumpling', 'id': 302575, 'score': 0.048652589321136475}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.04174366965889931}, {'name': 'Baked Sesame Nuggets', 'id': 141151, 'score': 0.04124700278043747}, {'name': 'Rice Florentine', 'id': 163036, 'score': 0.03501207381486893}, {'name': 'M & M Cookies', 'id': 882024, 'score': 0.03069480136036873}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.03060571663081646}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.022554771974682808}, {'name': 'Chefs Choice Fried Rice', 'id': 202001, 'score': 0.02158818580210209}, {'name': 'Fried Chicken Nuggets', 'id': 111037, 'score': 0.021339865401387215}, {'name': 'Panko Crusted Fish of the Day', 'id': 121049, 'score': 0.020948978140950203}, {'name': 'Bacon Cheddar Mashed Potatoes', 'id': 400915, 'score': 0.020840873941779137}, {'name': 'Raspberry Cheese Bar', 'id': 889063, 'score': 0.015859654173254967}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.014931769110262394}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.014888058416545391}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.014118773862719536}, {'name': 'Chefs Choice Lo Mein', 'id': 142046, 'score': 0.010579068213701248}, {'name': 'Halal Chicken Fajita', 'id': 299909, 'score': 0.00916497502475977}, {'name': 'Sauteed Brussels Sprouts', 'id': 400832, 'score': 0.0090680792927742}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.008449336513876915}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.00757356733083725}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.006101781036704779}, {'name': 'Beef and Broccoli Stir Fry', 'id': 300014, 'score': 0.0051489626057446}, {'name': 'Sweet Potato Black Bean Burger with Bun', 'id': 142210, 'score': 0.0024982632603496313}]
#
# {'items': [{'id': 171012, 'name': 'Corn', 'confidence': 0.98}], 'explanation': "The plate clearly contains yellow corn kernels that match the appearance of 'Corn' and no other menu items from the list are visibly present."}
# [GPT Item classification] 6.410s
# [Pulled nutrition info] 0.323s
# {'servings': [{'id': 171012, 'name': 'Corn', 'num_servings': 0.5}], 'explanation': 'Based on the visible amount versus a 3 oz serving, this appears to be about half a serving; estimate is conservative.'}
# [GPT Portion estimation] 8.168s
# === Total runtime: 24.320s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-27) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.352s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 9.816s
# [Generated image embedding] 0.153s
# [CLIP Ranking items] 0.001s
# [{'name': 'Zesty Fried Chicken Tenders', 'id': 111012, 'score': 0.1633034348487854}, {'name': 'Herb Buttered Corn', 'id': 300690, 'score': 0.10982003062963486}, {'name': 'Country Gravy', 'id': 151001, 'score': 0.09308701008558273}, {'name': 'Cajun Salmon W/ Honey Dill Mustard Sauce', 'id': 125025, 'score': 0.07554090023040771}, {'name': 'Cheddar Mashed Potatoes', 'id': 161023, 'score': 0.07489563524723053}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.06339986622333527}, {'name': 'Roasted Green Beans', 'id': 302989, 'score': 0.05289730802178383}, {'name': 'Chicken Noodle Soup', 'id': 23002, 'score': 0.04382702708244324}, {'name': 'Halal Chicken Nugget', 'id': 401028, 'score': 0.04323813319206238}, {'name': 'Mashed Red Potatoes with Garlic', 'id': 300575, 'score': 0.03860219195485115}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.036146361380815506}, {'name': 'Curly Fries', 'id': 161027, 'score': 0.027516670525074005}, {'name': 'Beyond Burger', 'id': 142188, 'score': 0.02174053154885769}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.01955161802470684}, {'name': 'Garlic Breadsticks', 'id': 303204, 'score': 0.018279487267136574}, {'name': 'Cheddar Broccoli Soup', 'id': 400931, 'score': 0.017177751287817955}, {'name': 'Halal Baby Carrots', 'id': 401007, 'score': 0.014010145328938961}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.013125737197697163}, {'name': 'Minestrone Soup', 'id': 410402, 'score': 0.01295169536024332}, {'name': 'Raspberry Streusel Bar', 'id': 882045, 'score': 0.010214265435934067}, {'name': 'Chickpea & Kale Stew', 'id': 410492, 'score': 0.010058541782200336}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.009841055609285831}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.00975296925753355}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.006375272758305073}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.005475400947034359}, {'name': 'Double Chocolate Chip Cookie', 'id': 882019, 'score': 0.00534496083855629}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.003826077561825514}]
#
# {'items': [{'id': 111012, 'name': 'Zesty Fried Chicken Tenders', 'confidence': 0.95}, {'id': 300690, 'name': 'Herb Buttered Corn', 'confidence': 0.92}, {'id': 161023, 'name': 'Cheddar Mashed Potatoes', 'confidence': 0.8}, {'id': 302989, 'name': 'Roasted Green Beans', 'confidence': 0.9}], 'explanation': 'The plate clearly shows breaded chicken tenders, a pile of yellow corn kernels, a scoop of creamy mashed potatoes, and a serving of green beans, matching the listed menu items.'}
# [GPT Item classification] 9.249s
# [Pulled nutrition info] 0.533s
# {'servings': [{'id': 111012, 'name': 'Zesty Fried Chicken Tenders', 'num_servings': 0.75}, {'id': 300690, 'name': 'Herb Buttered Corn', 'num_servings': 1.0}, {'id': 161023, 'name': 'Cheddar Mashed Potatoes', 'num_servings': 1.0}, {'id': 302989, 'name': 'Roasted Green Beans', 'num_servings': 1.0}], 'explanation': 'I estimate 3 chicken pieces (3/4 of a 4-EACH serving). Corn, mashed potatoes, and green beans each appear to be about one serving.'}
# [GPT Portion estimation] 13.605s
# === Total runtime: 33.880s ===
#
#
# === Running menumatch for new image (lunch, 2025-11-07) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.147s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 10.516s
# [Generated image embedding] 0.149s
# [CLIP Ranking items] 0.001s
# [{'name': 'Sweet Chili Wings', 'id': 400777, 'score': 0.2446133941411972}, {'name': 'Buffalo Wings', 'id': 111033, 'score': 0.1823662668466568}, {'name': 'Baked Rotisserie Chicken Wings', 'id': 300773, 'score': 0.17110604047775269}, {'name': 'Korean BBQ Pork Chops', 'id': 400762, 'score': 0.04480113461613655}, {'name': 'Halal Mongolian Beef', 'id': 300499, 'score': 0.03567831218242645}, {'name': 'Cross Trax French Fries', 'id': 161069, 'score': 0.02685704454779625}, {'name': 'Adobo Cod', 'id': 302988, 'score': 0.026327691972255707}, {'name': 'Ranger Cookies', 'id': 882064, 'score': 0.025381283834576607}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.024836808443069458}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.023607531562447548}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.02357330732047558}, {'name': 'Beyond Burger', 'id': 142188, 'score': 0.015882795676589012}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.013334442861378193}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.011950371786952019}, {'name': 'Roasted Cauliflower', 'id': 300660, 'score': 0.011257165111601353}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.011159872636198997}, {'name': 'Asparagus', 'id': 175031, 'score': 0.01074788998812437}, {'name': 'UConn Bleu Cheese Dressing', 'id': 221002, 'score': 0.010448280721902847}, {'name': 'Dirt Pudding', 'id': 886022, 'score': 0.010091540403664112}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.009737983345985413}, {'name': 'Focaccia Bruschetta', 'id': 400969, 'score': 0.008960790932178497}, {'name': 'Basmati Rice', 'id': 299916, 'score': 0.008844723924994469}, {'name': 'Chefs Choice Fried Rice', 'id': 202001, 'score': 0.008813546970486641}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.008631264790892601}, {'name': 'Chefs Choice Vegetable Stir Fry', 'id': 202000, 'score': 0.007148312870413065}, {'name': 'Steamed Broccoli', 'id': 401011, 'score': 0.006787706632167101}, {'name': 'Fresh Vegetable and Tofu Stir Fry', 'id': 300911, 'score': 0.006195300258696079}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.005686216522008181}, {'name': 'Cheddar Mashed Potatoes', 'id': 161023, 'score': 0.00517303217202425}]
#
# {'items': [{'id': 111033, 'name': 'Buffalo Wings', 'confidence': 0.95}], 'explanation': 'The plate clearly shows multiple fried chicken wings coated in an orange-red hot sauce consistent with buffalo-style wings, matching the visual appearance and the high-ranked candidate.'}
# [GPT Item classification] 5.657s
# [Pulled nutrition info] 0.338s
# {'servings': [{'id': 111033, 'name': 'Buffalo Wings', 'num_servings': 1.8}], 'explanation': 'Estimated 9 pieces on the plate; 5 pieces = 1 serving, so 9/5 = 1.8 servings.'}
# [GPT Portion estimation] 8.249s
# === Total runtime: 25.227s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-24) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.316s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 8.181s
# [Generated image embedding] 0.146s
# [CLIP Ranking items] 0.001s
# [{'name': 'Yellow Rice with Pigeon Peas', 'id': 163010, 'score': 0.33409643173217773}, {'name': 'Basmati Rice', 'id': 299916, 'score': 0.2657036781311035}, {'name': 'Cross Trax French Fries', 'id': 161069, 'score': 0.046171337366104126}, {'name': 'Black Beans In Sofrito', 'id': 302435, 'score': 0.03454631567001343}, {'name': 'Halal Baby Carrots', 'id': 401007, 'score': 0.030021775513887405}, {'name': 'Pernil', 'id': 300016, 'score': 0.026577385142445564}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.02638227492570877}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.023555392399430275}, {'name': 'Fajita Bar', 'id': 200092, 'score': 0.02092933841049671}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.017920518293976784}, {'name': 'Yucca Fries', 'id': 161025, 'score': 0.017536306753754616}, {'name': 'Halal Mongolian Beef', 'id': 300499, 'score': 0.016677800565958023}, {'name': 'Sweet Potato Black Bean Burger with Bun', 'id': 142210, 'score': 0.01659437082707882}, {'name': 'Lime Infused Swordfish', 'id': 121054, 'score': 0.01563229411840439}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.015407358296215534}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.012991109862923622}, {'name': 'Chocolate Drizzled Macaroons', 'id': 882025, 'score': 0.012275142595171928}, {'name': 'Grilled Pineapple', 'id': 300090, 'score': 0.011576290242373943}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.011315768584609032}, {'name': 'Apple Cheesecake Bar', 'id': 886055, 'score': 0.01121247373521328}, {'name': 'Baked Plantains', 'id': 160999, 'score': 0.010866251774132252}, {'name': 'Cinnamon Sugared Churros', 'id': 400963, 'score': 0.00617099367082119}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.006165067199617624}, {'name': 'Sauteed Spinach With Garlic', 'id': 302995, 'score': 0.006124843377619982}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.003549514804035425}]
#
# {'items': [{'id': 163010, 'name': 'Yellow Rice with Pigeon Peas', 'confidence': 0.92}], 'explanation': 'The plate shows long-grain, seasoned yellow-tinted rice mixed with small round pigeon-pea–like legumes, matching Yellow Rice with Pigeon Peas; no other listed items are visible.'}
# [GPT Item classification] 6.148s
# [Pulled nutrition info] 0.139s
# {'servings': [{'id': 163010, 'name': 'Yellow Rice with Pigeon Peas', 'num_servings': 2.0}], 'explanation': 'The rice mound appears about 1–1.25 cups cooked (~6 oz), which is approximately 2.0 servings at 3 oz per serving.'}
# [GPT Portion estimation] 8.376s
# === Total runtime: 23.460s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-29) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.147s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 10.698s
# [Generated image embedding] 0.215s
# [CLIP Ranking items] 0.001s
# [{'name': 'Macaroni & Cheese', 'id': 131007, 'score': 0.411227822303772}, {'name': 'Baked Beans', 'id': 141059, 'score': 0.05575878918170929}, {'name': 'Corn Cobettes', 'id': 171040, 'score': 0.05344647914171219}, {'name': 'Crinkle Cut Fries', 'id': 161028, 'score': 0.04870723932981491}, {'name': 'Tempura Battered Pickle Chips', 'id': 121006, 'score': 0.041982077062129974}, {'name': 'Chocolate Chip Delight', 'id': 882068, 'score': 0.04083975777029991}, {'name': 'Green Beans', 'id': 401002, 'score': 0.032447513192892075}, {'name': 'White Rice', 'id': 163002, 'score': 0.02665267325937748}, {'name': 'Halal Beef Lasagna', 'id': 142035, 'score': 0.025261081755161285}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.02511271834373474}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.024839062243700027}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.023955419659614563}, {'name': 'Vegan BBQ Beef', 'id': 400403, 'score': 0.021888481453061104}, {'name': 'Herbed Garlic Bread', 'id': 299911, 'score': 0.02162986621260643}, {'name': 'Snickerdoodle Cookies', 'id': 882014, 'score': 0.019109560176730156}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.0171296875923872}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.016962511464953423}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.014079979620873928}, {'name': 'BBQ Sauce', 'id': 200755, 'score': 0.013637678697705269}, {'name': 'Pulled Pork', 'id': 300744, 'score': 0.01324713695794344}, {'name': 'Sauteed Baby Bok Choy', 'id': 302228, 'score': 0.01105842087417841}, {'name': 'Malibu Veggie Burger w/ Bun', 'id': 142183, 'score': 0.01016329973936081}, {'name': 'Orange Chicken Stir Fry', 'id': 111142, 'score': 0.008464313112199306}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.0074607632122933865}, {'name': 'Kielbasa Dogs', 'id': 85021, 'score': 0.004613132681697607}, {'name': 'Collard Greens with Applewood Bacon', 'id': 300730, 'score': 0.0038145652506500483}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.00377569324336946}, {'name': 'Singapore Street Noodles with Shrimp', 'id': 300884, 'score': 0.0027343144174665213}]
#
# {'items': [{'id': 131007, 'name': 'Macaroni & Cheese', 'confidence': 0.93}], 'explanation': 'The plate clearly shows elbow macaroni in a creamy cheese sauce with a browned breadcrumb topping, matching classic baked macaroni and cheese appearance.'}
# [GPT Item classification] 5.548s
# [Pulled nutrition info] 0.327s
# {'servings': [{'id': 131007, 'name': 'Macaroni & Cheese', 'num_servings': 1.5}], 'explanation': 'Conservatively estimated about 1.5 servings (≈9 oz) of macaroni & cheese on the plate based on the visible portion.'}
# [GPT Portion estimation] 7.291s
# === Total runtime: 24.407s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-31) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.164s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 9.414s
# [Generated image embedding] 0.167s
# [CLIP Ranking items] 0.001s
# ...
#
# {'items': [{'id': 300690, 'name': 'Herb Buttered Corn', 'confidence': 0.95}], 'explanation': 'The plate clearly shows yellow corn kernels with a buttery sheen and small herb flecks, matching Herb Buttered Corn; no other menu items are visible.'}
# [GPT Item classification] 5.000s
# [Pulled nutrition info] 0.138s
# {'servings': [{'id': 300690, 'name': 'Herb Buttered Corn', 'num_servings': 0.67}], 'explanation': 'The pile appears about one-third cup (~2 oz) of kernels, roughly 0.67 of the 3 oz serving size.'}
# [GPT Portion estimation] 10.029s
# === Total runtime: 25.321s ===
#
#
# === Running menumatch for new image (lunch, 2025-11-03) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.153s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 9.894s
# [Generated image embedding] 0.150s
# [CLIP Ranking items] 0.001s
# [{'name': 'Bacon Crumbles', 'id': 200318, 'score': 0.23552177846431732}, {'name': 'Macaroni & Cheese', 'id': 200692, 'score': 0.10705742985010147}, {'name': 'Fried Cabbage', 'id': 304027, 'score': 0.0826454907655716}, {'name': 'Halal Cajun Chicken', 'id': 300489, 'score': 0.05783409625291824}, {'name': 'Cheddar Beer Cheese', 'id': 302822, 'score': 0.052548978477716446}, {'name': 'Jalapenos', 'id': 200305, 'score': 0.051943931728601456}, {'name': 'Herb Grilled Tofu', 'id': 400895, 'score': 0.03943168371915817}, {'name': 'Steamed Broccoli', 'id': 200425, 'score': 0.03558528795838356}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.033637333661317825}, {'name': 'Potato & Cheese Pierogi', 'id': 300737, 'score': 0.03242531418800354}, {'name': 'Roasted Potato Medley', 'id': 299918, 'score': 0.031454358249902725}, {'name': 'Roasted Chicken', 'id': 200396, 'score': 0.027435246855020523}, {'name': 'Beyond Meat Beef Strips', 'id': 142190, 'score': 0.024039829149842262}, {'name': 'Buffalo Sauce', 'id': 200602, 'score': 0.022119635716080666}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.02116764895617962}, {'name': 'Curly Fries', 'id': 161027, 'score': 0.02077546715736389}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.016640545800328255}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.01456303708255291}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.014342883601784706}, {'name': 'Beyond Burger', 'id': 142188, 'score': 0.013304036110639572}, {'name': 'Pumpkin Spice Blondies', 'id': 889035, 'score': 0.012846536934375763}, {'name': 'Soft Pretzel', 'id': 12020, 'score': 0.010237960144877434}, {'name': 'Summer Vegetable Medley', 'id': 300974, 'score': 0.010156534612178802}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.007767768576741219}, {'name': 'Red ,White & Blue Cookies', 'id': 882063, 'score': 0.005902406293898821}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.005550168454647064}, {'name': 'Kielbasa', 'id': 85022, 'score': 0.0054723769426345825}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.005151028279215097}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.0024411824997514486}]
#
# {'items': [{'id': 200692, 'name': 'Macaroni & Cheese', 'confidence': 0.95}, {'id': 200318, 'name': 'Bacon Crumbles', 'confidence': 0.45}], 'explanation': 'The plate clearly shows elbow pasta coated in a creamy cheese sauce consistent with macaroni & cheese; the scattered small brown crispy pieces look like bacon crumbles rather than a vegetable or large topping, so I included them with moderate confidence.'}
# [GPT Item classification] 7.027s
# [Pulled nutrition info] 0.284s
# {'servings': [{'id': 200692, 'name': 'Macaroni & Cheese', 'num_servings': 0.7}, {'id': 200318, 'name': 'Bacon Crumbles', 'num_servings': 0.1}], 'explanation': 'I estimate about 0.7 serving of macaroni & cheese from the visible portion; the bacon crumbles are sparse so I estimate about 0.1 serving.'}
# [GPT Portion estimation] 11.773s
# === Total runtime: 29.544s ===
#
#
# === Running menumatch for new image (dinner, 2025-10-22) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.322s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 6.314s
# [Generated image embedding] 0.174s
# [CLIP Ranking items] 0.001s
# [{'name': 'Jasmine Rice', 'id': 400711, 'score': 0.47597962617874146}, {'name': 'Shrimp Egg Foo Yung', 'id': 300656, 'score': 0.10209950804710388}, {'name': 'Cannoli', 'id': 889071, 'score': 0.06399839371442795}, {'name': 'Three Cheese Bread', 'id': 811018, 'score': 0.054326336830854416}, {'name': 'Spaghetti', 'id': 165001, 'score': 0.050605446100234985}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.03654398024082184}, {'name': 'Fortune Cookies', 'id': 601156, 'score': 0.035959336906671524}, {'name': 'Corn & Bacon Chowder', 'id': 300876, 'score': 0.0346202477812767}, {'name': 'Crinkle Cut Fries', 'id': 161028, 'score': 0.03313162922859192}, {'name': "General Tso's Chicken", 'id': 111083, 'score': 0.03019697219133377}, {'name': 'Baked Ziti', 'id': 141091, 'score': 0.02081245370209217}, {'name': 'Mini Vegetable Egg Rolls', 'id': 142220, 'score': 0.020549340173602104}, {'name': 'Chefs Choice Lo Mein', 'id': 142046, 'score': 0.013764657080173492}, {'name': 'Veggie Strip Stir Fry', 'id': 300685, 'score': 0.012910546734929085}, {'name': 'Beef Cheeseburger w/ Bun', 'id': 73008, 'score': 0.007821773178875446}, {'name': 'Summer Vegetable Medley', 'id': 300974, 'score': 0.006679793354123831}]
#
# {'items': [{'id': 400711, 'name': 'Jasmine Rice', 'confidence': 0.9}, {'id': 300974, 'name': 'Summer Vegetable Medley', 'confidence': 0.3}], 'explanation': 'The plate clearly shows long-grain white rice (consistent with jasmine rice) plus small green florets and sauce remnants consistent with mixed vegetables; there are no visible noodles, egg patties, or pastry items.'}
# [GPT Item classification] 13.182s
# [Pulled nutrition info] 0.446s
# {'servings': [{'id': 400711, 'name': 'Jasmine Rice', 'num_servings': 1.5}, {'id': 300974, 'name': 'Summer Vegetable Medley', 'num_servings': 0.2}], 'explanation': 'Conservative visual estimates: roughly one to one-and-a-half small scoops of rice (~1.5 servings of 3 oz each) and only a few small vegetable pieces (~0.2 of a 3 oz serving).'}
# [GPT Portion estimation] 9.974s
# === Total runtime: 30.493s ===
#
#
# === Running menumatch for new image (lunch, 2025-10-24) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.155s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 9.743s
# [Generated image embedding] 0.156s
# [CLIP Ranking items] 0.001s
# [{'name': 'Pernil', 'id': 300016, 'score': 0.36162906885147095}, {'name': 'Halal Mongolian Beef', 'id': 300499, 'score': 0.06884917616844177}, {'name': 'Cross Trax French Fries', 'id': 161069, 'score': 0.06471127271652222}, {'name': 'Baked Plantains', 'id': 160999, 'score': 0.04692062735557556}, {'name': 'Lime Infused Swordfish', 'id': 121054, 'score': 0.04488985240459442}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.03979344666004181}, {'name': 'Yucca Fries', 'id': 161025, 'score': 0.03959636762738228}, {'name': 'Basmati Rice', 'id': 299916, 'score': 0.036563243716955185}, {'name': 'Fajita Bar', 'id': 200092, 'score': 0.03126024082303047}, {'name': 'Grilled Pineapple', 'id': 300090, 'score': 0.03092353604733944}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.0289877038449049}, {'name': 'Chocolate Drizzled Macaroons', 'id': 882025, 'score': 0.026855366304516792}, {'name': 'Halal Baby Carrots', 'id': 401007, 'score': 0.026280777528882027}, {'name': 'Yellow Rice with Pigeon Peas', 'id': 163010, 'score': 0.02627040259540081}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.02303539216518402}, {'name': 'Black Beans In Sofrito', 'id': 302435, 'score': 0.022073009982705116}, {'name': 'Apple Cheesecake Bar', 'id': 886055, 'score': 0.020714513957500458}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.010745124891400337}, {'name': 'Cinnamon Sugared Churros', 'id': 400963, 'score': 0.010618319734930992}, {'name': 'Sauteed Spinach With Garlic', 'id': 302995, 'score': 0.00915997102856636}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.008501979522407055}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.008132772520184517}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.006556442007422447}, {'name': 'Sweet Potato Black Bean Burger with Bun', 'id': 142210, 'score': 0.0041686734184622765}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.002762767719104886}]
#
# {'items': [{'id': 300016, 'name': 'Pernil', 'confidence': 0.92}], 'explanation': 'The plate shows shredded, roasted pork pieces with visible fat and texture consistent with pernil; no other menu items (rice, fries, or vegetables) are visible.'}
# [GPT Item classification] 4.010s
# [Pulled nutrition info] 0.133s
# {'servings': [{'id': 300016, 'name': 'Pernil', 'num_servings': 1.5}], 'explanation': 'Estimated ~6 oz of shredded pernil on the plate (serving size 4 oz), so about 1.5 servings.'}
# [GPT Portion estimation] 11.073s
# === Total runtime: 25.428s ===
#
#
# === Running menumatch for new image (lunch, 2025-11-21) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.138s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 9.261s
# [Generated image embedding] 0.160s
# [CLIP Ranking items] 0.001s
# [{'name': 'Baked Sesame Nuggets', 'id': 141151, 'score': 0.28339090943336487}, {'name': 'Fried Chicken Nuggets', 'id': 111037, 'score': 0.24453744292259216}, {'name': 'M & M Cookies', 'id': 882024, 'score': 0.07278169691562653}, {'name': 'Edamame Dumpling', 'id': 302575, 'score': 0.0426165908575058}, {'name': 'Grilled Chicken Breast', 'id': 111027, 'score': 0.03768044710159302}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.033485885709524155}, {'name': 'Corn', 'id': 171012, 'score': 0.03288493677973747}, {'name': 'Cross Trax French Fries', 'id': 161069, 'score': 0.030683493241667747}, {'name': 'Raspberry Cheese Bar', 'id': 889063, 'score': 0.02550826407968998}, {'name': 'Panko Crusted Fish of the Day', 'id': 121049, 'score': 0.02275223657488823}, {'name': 'Rice Florentine', 'id': 163036, 'score': 0.01919107884168625}, {'name': 'Beef Burger No Bun', 'id': 73000, 'score': 0.01727261394262314}, {'name': 'Sweet Potato Black Bean Burger with Bun', 'id': 142210, 'score': 0.015175451524555683}, {'name': 'Special Pizza', 'id': 400442, 'score': 0.014745988883078098}, {'name': 'Sauteed Brussels Sprouts', 'id': 400832, 'score': 0.014521516859531403}, {'name': 'Halal Chicken Fajita', 'id': 299909, 'score': 0.01286607701331377}, {'name': 'Grilled Hot Dogs', 'id': 77026, 'score': 0.01168728992342949}, {'name': 'Bacon Cheddar Mashed Potatoes', 'id': 400915, 'score': 0.010291769169270992}, {'name': "Chef's Choice Soup du Jour", 'id': 410814, 'score': 0.010137706995010376}, {'name': 'Pepperoni Pizza', 'id': 400441, 'score': 0.009979510679841042}, {'name': 'Marinara Sauce', 'id': 153001, 'score': 0.009726975113153458}, {'name': 'Chefs Choice Fried Rice', 'id': 202001, 'score': 0.009673078544437885}, {'name': 'Cheese Pizza', 'id': 400440, 'score': 0.008974862284958363}, {'name': 'Chefs Choice Lo Mein', 'id': 142046, 'score': 0.005797946359962225}, {'name': 'Beef and Broccoli Stir Fry', 'id': 300014, 'score': 0.0036362772807478905}]
#
# {'items': [{'id': 111037, 'name': 'Fried Chicken Nuggets', 'confidence': 0.95}], 'explanation': 'The plate clearly shows multiple small, golden-brown breaded nuggets consistent with fried chicken nuggets (shape and texture match); there are no visible sesame seeds or other items present.'}
# [GPT Item classification] 5.226s
# [Pulled nutrition info] 0.335s
# {'servings': [{'id': 111037, 'name': 'Fried Chicken Nuggets', 'num_servings': 2.17}], 'explanation': 'I count 13 pieces on the plate; with a serving = 6 each, 13/6 ≈ 2.17 servings.'}
# [GPT Portion estimation] 11.517s
# === Total runtime: 26.784s ===
#
#
# === Running menumatch for new image (dinner, 2025-10-22) ===
# [Loaded image] 0.000s
# [Loaded menu items] 0.133s
# [Prepared prompt variants] 0.000s
# [Generated text embeddings] 5.695s
# [Generated image embedding] 0.167s
# [CLIP Ranking items] 0.000s
# [{'name': "General Tso's Chicken", 'id': 111083, 'score': 0.3446924686431885}, {'name': 'Shrimp Egg Foo Yung', 'id': 300656, 'score': 0.1344238519668579}, {'name': 'Fortune Cookies', 'id': 601156, 'score': 0.11787834018468857}, {'name': 'Mini Vegetable Egg Rolls', 'id': 142220, 'score': 0.08022122830152512}, {'name': 'Crinkle Cut Fries', 'id': 161028, 'score': 0.05779722332954407}, {'name': 'Veggie Strip Stir Fry', 'id': 300685, 'score': 0.055523719638586044}, {'name': 'Chefs Choice Lo Mein', 'id': 142046, 'score': 0.04918016120791435}, {'name': 'Jasmine Rice', 'id': 400711, 'score': 0.027943279594182968}, {'name': 'Summer Vegetable Medley', 'id': 300974, 'score': 0.0277456883341074}, {'name': 'Cannoli', 'id': 889071, 'score': 0.023951455950737}, {'name': 'Three Cheese Bread', 'id': 811018, 'score': 0.01856807991862297}, {'name': 'Grilled Cheese', 'id': 138005, 'score': 0.015103551559150219}, {'name': 'Spaghetti', 'id': 165001, 'score': 0.013320832513272762}, {'name': 'Corn & Bacon Chowder', 'id': 300876, 'score': 0.011858801357448101}, {'name': 'Baked Ziti', 'id': 141091, 'score': 0.011858467943966389}, {'name': 'Beef Cheeseburger w/ Bun', 'id': 73008, 'score': 0.009932850487530231}]
#
# {'items': [{'id': 111083, 'name': "General Tso's Chicken", 'confidence': 0.95}, {'id': 400711, 'name': 'Jasmine Rice', 'confidence': 0.6}], 'explanation': "The plate shows bite-sized battered pieces in a glossy orange-brown sauce with broccoli florets consistent with General Tso's Chicken, and there are visible white rice grains scattered on top indicating jasmine rice."}
# [GPT Item classification] 7.533s
# [Pulled nutrition info] 0.614s
# {'servings': [{'id': 111083, 'name': "General Tso's Chicken", 'num_servings': 1.0}, {'id': 400711, 'name': 'Jasmine Rice', 'num_servings': 0.2}], 'explanation': "Conservative estimate of one full serving of General Tso's chicken and a small scattered amount of rice (~0.2 serving)."}
# [GPT Portion estimation] 18.914s
# === Total runtime: 33.138s ===
#
# cls_precision             0.8478
# cls_recall                0.9512
# cls_f1                    0.8966
# cls_avg_jaccard           0.8621
# cls_exact_match           0.7586
# portion_mae_servings      0.4023
# portion_rmse_servings     0.6411
# portion_pmae_servings     0.3014
# macro_mae_kcal            70.9783
# macro_pmae_kcal           0.2130
# macro_mae_protein_g       4.6207
# macro_pmae_protein_g      0.2225
# macro_mae_carb_g          6.9857
# macro_pmae_carb_g         0.3992
# macro_mae_fat_g           4.1269
# macro_pmae_fat_g          0.2209
